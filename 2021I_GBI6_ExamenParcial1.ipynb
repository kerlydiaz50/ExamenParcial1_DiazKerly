# %% [markdown]
# ![logoikiam.png](attachment:b58ecf93-06c2-4d1e-bf03-0f47b106e0a7.png)
#
# # EXAMEN PARCIAL 1
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Díaz Solórzano, Kerly Jamileth**
#
# **11-01-2021**

# %% [markdown]
# <font color='red'>NO AGREGUE NUEVAS CELDAS, UTILICE ÚNICAMENTE LAS QUE ESTÁN CREADAS</font>

# %% [markdown]
# # 1. UNIX
#
# ## Ejercicio 1
# Seleccione la opción el código que imprime el texto: *Hola GBI6*
#
# ![ejercicio_1.PNG](attachment:5a32ea77-f48d-4545-a00c-b4a07c01f22b.PNG)
#
# **echo** es el comando que permite imprimir textos.
#
# ## Ejercicio 2
# Para esta pregunta debe realizar previamente lo siguiente:
#
# 1. Imprimir el directorio de trabajo actual
# 2. Crear un directorio *test1*
# 3. **No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2**.
# 4. Crear el archivo *test1.txt*
# 5. Guardar el texto *Hola GBI6* en un archivo *test2.txt*
# 6. Guardar la instrucción *print("Hola GBI6")* en el archivo *test1.py*
#
# **Luego seleccione la instrucción que permite enlistar el contenido (incluyendo detalles) del directorio test1**
#
# ![ejercicio_2.PNG](attachment:cb0db90b-fec6-4a90-af97-bb8de7e6bd5f.PNG)
#
# Para imprimir el nombre del directorio del trabajo actual se empleó el comando **pwd**, después ya localizado en qué directorio se encuentra el usuario se creo el directorio **test1** con el comando **mkdir**, para crear el siguiente archivo **test1.txt** y guardarlo en el mismo directorio creado previamente se empleó la siguiente línea de comando: **touch test1/test1.txt**. Posteriormente, para guardar el texto mencionado en el numeral 5, en el archivo **text2.txt** y mantenerlo en el directorio **test1** se empleó la línea de comando: **echo "Hola GBI6" > test1/test2.txt**. Después para crear el archivo **test1.py**, se utilizó el comando **touch** y se guardó en el directorio test1 (**touch test1/test1.py**), para escribir y guardar la instrucción **print("Hola GBI6")** se escribió el comando **nano test1/test1.py**.
#
# Finalmente, para enlistar y ver con detalle el contenido del directorio **test1**, se escribieron los siguientes comandos:
# - ls -l test1
# - ls -lh test1/
# - ls -l ./test1
#
# El contenido de este directorio se puede observar en la captura del *ejercicio_2*.
#
# ## Ejercicio 3
# Para esta pregunta debe realizar previamente lo siguiente:
#
# 1. Imprimir el directorio de trabajo actual
# 2. Crear un directorio test1
# 3. **No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.**
# 4. Crear el archivo test1.txt
# 5. Guardar el texto Hola GBI6 en un archivo *test2.txt*
# 6. Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
#
# **Luego seleccione la instrucción que permite enlistar el contenido (sin detalles) del directorio test1**
#
# ![ejercicio_3.PNG](attachment:1b8d6108-94d4-4e56-93af-cd479f9fe074.PNG)
#
# - ls ./test1
# - ls test1/
# - ls test1
#
# ## Ejercicio 4
# Resuelva el ejercicio **1.10.2 Hormone Levels in Baboons.**
#
# 1. Resuelva el ejercicio en un documento de nombre **ejercicio_1102.sh**
# 2. Cargue el documento **ejercicio_1102.sh** en GitHub utilizando **git push.**
# 3. Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de Jupyter.

# %%
# Coloque aquí su video del ejercicio 4
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/9ck5iEP03g4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9ck5iEP03g4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Escriba aquí alguna explicación del ejercicio 4 si lo considera necesario (borre esta línea cuando finalice)
#
# ## Ejercicio 5
# Resuelva el ejercicio **1.10.4 Data Explorer.**
#
# 1. Resuelva el ejercicio en un documento de nombre **ejercicio_1104.sh**
# 2. Cargue el documento **ejercicio_1104.sh** en GitHub utilizando **git push.**
# 3. Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de  Jupyter.

# %%
# Coloque aquí su video del ejercicio 5
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/3XlZWpLwvvo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3XlZWpLwvvo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Escriba aquí alguna explicación del ejercicio 5 si lo considera necesario (borre esta línea cuando finalice)
#
# # 2. CONTROL DE LA VERSIÓN
# ## Pregunta 6
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenParcial1```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Programas utilizados
# - Explicación de la data utilizada
#
#
# ## Pregunta 7
# 1. Cada vez que resuelva un ejercicio (del 1 al 10), utilizando Git Bash, GitHub Desktop o Atom realice un *git push* con el mensaje:
#
#
# <font color='red'>Apellido Nombre ha resuelto el ejercicio 1</font> % Cambie con sus apellidos y nombres; y con el número de ejercicio que corresponda
#
# 2. Coloque aquí las capturas de pantalla para cada git push realizado desde Git Bash, GitHub Desktop o Atom.
#
# - Control de versión ejercicio 1
#
# ![gitpush_ejercicio1.1.PNG](attachment:8214dc46-bcd5-45b6-91cf-9b1e2ae09f2c.PNG)
# ![gitpush_ejercicio1.2.PNG](attachment:7b45260b-37de-42cf-8379-353c1fc4a367.PNG)
#
# - Control de versión ejercicio 2
#
# ![gitpush_ejercicio2.PNG](attachment:d32ea709-0f91-4845-bc94-5d25a1889abd.PNG)
#
# - Control de versión ejercicio 3
#
# ![gitpush_ejercicio3.PNG](attachment:d06ea39c-f2d5-4801-8f85-d633471ea335.PNG)
#
# - Control de versión ejercicio 4
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 5
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 8
#
# ![gitpush_ejercicio8.PNG](attachment:0bf583c5-f273-465f-a3f2-a24d9801afa2.PNG)
#
# - Control de versión ejercicio 9
#
# ![gitpush_ejercicio9.PNG](attachment:16a32b14-cd7b-4987-ab5d-5c2dbcfded4f.PNG)
#
# - Control de versión ejercicio 10
#
# ![gitpush_ejercicio10.PNG](attachment:455c4936-5f1b-47e4-b8ee-8741d68f7969.PNG)
#
#
# 3. Cree un directorio de nombre ```data``` donde deben estar guardados: (i) la data utilizada y (ii) las capturas de pantalla de los ejercicios 1 al 3 y los git push del ejercicio 1 al 10 (en total debe tener 13 imágenes).
# 4. Inserte aquí el enlace de su repositorio (válido para el ejercicio 6 y 7): [GitHub Repository: GBI6_ExamenParcial1](https://github.com/gualapuromoises/2021_gbi6.git) (este enlace es de ejemplo)

# %% [markdown]
# # 3. INTRODUCCIÓN A PYTHON
#
# ## Ejercicio 8
#
# Para este ejercicio debe debe realizar lo siguiente:
#
# 1. Crear un diccionario de nombre dic_aminoacidos, donde se tenga la información de la tabla que se encuentra en http://www.russelllab.org/aas/aas.html.
# 2. Utilice como "key" los valores de la columna "AA" y las columnas "Hits" y "%Abundance" como "values".
# 3. Luego de crear el diccionario, extraiga los valores de "key" a una lista de nombre "aminoacidos"
# 4. Extraiga los valores de "value" a una lista de nombre "propiedades"

# %%
# Numeral 1 y 2
# Se crea un diccionario donde haya múltiples valores/values asociados con una clave/key
# key corresponde a "AA"
# Los values corresponden a "Hits" y "%Abundance"
dic_aminoacidos = {"Trp": [1550, 1.34],
                   "Cys": [1905, 1.76],
                   "His": [1695, 2.26],
                   "Arg": [3093, 5.20],
                   "Met": [1102, 2.32],
                   "Tyr": [1525, 3.25],
                   "Gln": [1830, 3.96],
                   "Phe": [1616, 4.12],
                   "Asp": [1691, 5.12],
                   "Pro": [1598, 5.00],
                   "Ala": [2018, 7.34],
                   "Asn": [1103, 4.57],
                   "Lys": [1366, 5.81],
                   "Glu": [1471, 6.22],
                   "Gly": [1386, 6.89],
                   "Thr": [1147, 5.85],
                   "Val": [1225, 6.48],
                   "Ile": [1033, 5.76],
                   "Ser": [1206, 7.38],
                   "Leu": [1127, 9.36]
                  }
print(dic_aminoacidos)

# Numeral 3
aminoacidos = dic_aminoacidos.keys() # Si se necesitan las keys del diccionario se emplea dicha función 
print("El tipo de variable de aminoacidos es: ", type(aminoacidos)) # Para imprimir y/o verificar el tipo de variable de la lista 

aminoacidos = list(aminoacidos)

print("Impresión de la lista completa que contiene todas las keys: ")  
print(aminoacidos)

print("Imprimiendo keys individuales almacenadas en la lista: ")

for key in aminoacidos:
    print(key)
    
# Numeral 4
propiedades = dic_aminoacidos.values() # Si se necesitan los values del diccionario se emplea dicha función 
print("El tipo de variable de propiedades es: ", type(propiedades)) # Para imprimir y/o verificar el tipo de variable de la lista 

propiedades = list(propiedades)

print("Imprimiendo la lista completa que contiene todos los values: ")
print(propiedades)

print("Imprimiendo values individuales almacenados en la lista: ")

for val in propiedades:
    print(val)
# Out:
# {'Trp': [1550, 1.34], 'Cys': [1905, 1.76], 'His': [1695, 2.26], 'Arg': [3093, 5.2], 'Met': [1102, 2.32], 'Tyr': [1525, 3.25], 'Gln': [1830, 3.96], 'Phe': [1616, 4.12], 'Asp': [1691, 5.12], 'Pro': [1598, 5.0], 'Ala': [2018, 7.34], 'Asn': [1103, 4.57], 'Lys': [1366, 5.81], 'Glu': [1471, 6.22], 'Gly': [1386, 6.89], 'Thr': [1147, 5.85], 'Val': [1225, 6.48], 'Ile': [1033, 5.76], 'Ser': [1206, 7.38], 'Leu': [1127, 9.36]}
# El tipo de variable de aminoacidos es:  <class 'dict_keys'>
# Impresión de la lista completa que contiene todas las keys:
# ['Trp', 'Cys', 'His', 'Arg', 'Met', 'Tyr', 'Gln', 'Phe', 'Asp', 'Pro', 'Ala', 'Asn', 'Lys', 'Glu', 'Gly', 'Thr', 'Val', 'Ile', 'Ser', 'Leu']
# Imprimiendo keys individuales almacenadas en la lista:
# Trp
# Cys
# His
# Arg
# Met
# Tyr
# Gln
# Phe
# Asp
# Pro
# Ala
# Asn
# Lys
# Glu
# Gly
# Thr
# Val
# Ile
# Ser
# Leu
# El tipo de variable de propiedades es:  <class 'dict_values'>
# Imprimiendo la lista completa que contiene todos los values:
# ...

# %% [markdown]
# ## Ejercicio 9
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# En la data https://github.com/sap0408/mtcars/blob/master/mtcars.csv, seleccione los 10 primeros registros y cree una lista de nombre *lista1.*

# %%
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
print(lista1) # Para imprimir la lista1

# Primer ejercicio
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
lista1[2:5] 
print(lista1[2:5])

# Segundo ejercicio
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
lista1[3]
print(lista1[3])

# Tercer ejercicio
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
lista1.append(["gbi6", "bio1", "ikiam"])
lista1[-1][-3]
print(lista1[-1][-3])

# Cuarto ejercicio
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
lista1[4]
print(lista1[4])

# Quinto ejercicio
lista1 = ["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280"]
lista1.append(["gbi6", "bio1", "ikiam"])
len(lista1)
print(len(lista1))
# Out:
# ['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive', 'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230', 'Merc 280']
# ['Datsun 710', 'Hornet 4 Drive', 'Hornet Sportabout']
# Hornet 4 Drive
# gbi6
# Hornet Sportabout
# 11

# %% [markdown]
# ## Ejercicio 10
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# Descargue la data "SI Table 1" (10080Table1.xls) de la página https://www.pnas.org/content/suppl/2006/12/27/0610080104.DC1. Esta data corresponde a algunas características de sueño de mamíferos. Seleccione los 10 primeros registros de la columna "Total sleep time, hr" y cree una lista de nombre *lista1.*

# %%
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
print(lista1) # Para imprimir la lista1

# Primer ejercicio
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
sum(lista1)/len(lista1)
print(sum(lista1)/len(lista1))

# Segundo ejercicio
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
lista1.append(["gbi6", "bio1", "ikiam"])
lista1[-1][2]
print(lista1[-1][2])

# Tercer ejercicio
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
lista1[8:]
print(lista1[8:])

# Cuarto ejercicio
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
round(sum(lista1)/len(lista1),3)
print(round(sum(lista1)/len(lista1),3))

# Quinto ejercicio 
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
lista1.extend(["gbi6", "bio1", "ikiam"])
len(lista1)
print(len(lista1))

# Sexto ejercicio
lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
lista1[5]
print(lista1[5])
# Out:
# [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
# 13.079999999999998
# ikiam
# [14.9, 9.1]
# 13.08
# 13
# 10.1
